# %% [markdown]
# # 函数进阶

# %% [markdown]
# # 1. 参数的补充
# ## 1.1 参数内存地址
# 查看某个值的内存地址

# %%
v1 = "abc"
addr = id(v1)

# %%
addr
# Out:
# 2439219301488

# %% [markdown]
# 函数执行传参时，传递的时内存地址。

# %% [markdown]
# 参数是可变类型：list/dict/色图 & 在函数内部智能对内部元素进行修改

# %% [markdown]
# 函数的deepcopy

# %% [markdown]
# ## 1.2 函数的返回值是内存地址

# %% [markdown]
# # 1.4 动态参数
# 执行函数时，也可以用*，**。

# %%
# 形参固定

# %%
def func(a1, a2):
    print(a1, a2)

func(11, 22)
func(
# Out:
#   Cell In[6], line 5
#     func(
#          ^
# SyntaxError: unexpected EOF while parsing

# %% [markdown]
# ![image.png](attachment:baf14480-4a7e-411f-b3b4-f0dbb44bd250.png)

# %% [markdown]
# # 2. 函数和函数名
# 解释型语言，函数先定义才能执行。
# ## 2.1 函数做元素

# %%
def func():
    return 123

data_list = ["张三", "func", func, func()]
